# %%
# %matplotlib inline
import pandas as pd
data = pd.read_csv('sp500-date.csv', index_col='Date', parse_dates=['Date'])
data['SMA'] = data['SP500'].rolling(2).mean()
data.plot()

# %%
# Out:
#              SP500  SMA
# Date
# 1996-01-02  123.32  NaN
# 1996-01-03  234.34  NaN
# 1996-01-04  345.22  NaN
# 1996-01-10  456.22  NaN
# 1996-01-11  456.33  NaN
# 1996-01-12  234.33  NaN
# 1996-01-22  565.33  NaN
# 1996-01-23  456.33  NaN
# 1996-01-24  546.57  NaN
# 1996-01-30  456.76  NaN
